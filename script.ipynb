# %%
import csv
import re
import pandas as pd
from openpyxl import load_workbook
import numpy

# %%
# Open the CSV file in read mode
with open('test2.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Close the file
csv_file.close()

# Open the CSV file in write mode
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the new headers to the file
    writer.writerow(['title', 'category', 'start', 'end', 'organizer', 'response', 'attendees', 'recurring', 'recurrence', 'recurrence end'])
    # Write the contents of the file (excluding the original header) to the file
    writer.writerows(contents[1:])
    
# Clean data
for row in contents:
    # Remove all commas
    row = [x.strip(',') for x in row]

for row in contents:
    # Replace any instances of 2 quotations with one quotation
    row = [x.replace('""', '"') for x in row]

for row in contents: 
    # Replace quotations with commas
    row = [x.replace('"', ',') for x in row]

for row in contents:
    # Replace double commas with single comma
    row = [x.replace(',,', ',') for x in row]

for i, row in enumerate(contents):
    # Split the row by comma
    contents[i] = row[0].split(',')

    
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    
    # Write the modified contents of the file to the file
    writer.writerows(contents)
    
# Close the file
csv_file.close()

# %%
# Open the CSV file in read mode
with open('output.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Close the file
csv_file.close()

# Iterate over the rows in the file
for i, row in enumerate(contents):
    # Remove all leading and trailing quotation marks
    contents[i] = [x.strip('"') for x in row]

# Open the CSV file in write mode
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the modified contents of the file to the file
    writer.writerows(contents)
    
# Close the file
csv_file.close()

# %%
# Open the input CSV file in read mode
with open('output.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Create a list to store the rows that need to be moved to the new file
headers = contents[0]

# Close the file
csv_file.close()

# grab all rows without yes or no in recurring column, have any letter in attendees column, or doesnt start with 2 in recurrence end column
contents2 = [row for row in contents if (row[7] not in ['yes', 'no'] or any(c.isalpha() for c in row[6])) or not row[9].startswith("2")]

# Open the output CSV file in write mode
with open('corrupt_data.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the headers to the file
#     writer.writerow(headers)
    # Write the rows from the contents2 list
    writer.writerows(contents2)

# Close the file
csv_file.close()

# Open the output CSV file in write mode
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the headers to the file
    writer.writerow(headers)
    # Write the rows from the contents list that are not in the contents2 list to the file
    writer.writerows([row for row in contents if row not in contents2])

# Close the file
csv_file.close()

# %%
# Remove rows with only one attendee (likely time block or WP event) or non recurring meetings

# Open the corrupt_data CSV file in read mode
with open('corrupt_data.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Create a list to store the modified rows
modified_rows = []

# Iterate over the rows in the contents
for row in contents:
    # Check if the value in the "recurring" column is "no" or the value in the "attendees" column is 1
    if row[7] == "no" or row[6] == "1":
        # Skip this row and move on to the next one
        continue
    # Add the modified row to the list
    modified_rows.append(row)

# Open the corrupt_data CSV file in write mode
with open('corrupt_data.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the modified rows to the file
    writer.writerows(modified_rows)

# Close the file
csv_file.close()

# Open the output CSV file in read mode
with open('output.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Get the headers from the contents
headers = contents[0]

# Create a new list to store the modified rows
modified_rows = []

# Iterate over the rows in the contents
for row in contents:
    # Check if the value in the "recurring" column is "no" or the value in the "attendees" column is 1
    if row[7] == "no" or row[6] == "1":
        # Skip this row and move on to the next one
        continue
    # Add the modified row to the list
    modified_rows.append(row)

# Open the output CSV file in write mode
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    
    # Write the modified rows to the file
    writer.writerows(modified_rows)

# Close the file
csv_file.close()

# %%
# Drop start and end columns from output file

# Open the input CSV file in read mode
with open('output.csv', 'r') as csv_file:
    # Create a csv.reader object
    reader = csv.reader(csv_file)
    # Read the contents of the file
    contents = list(reader)

# Create a list to store the rows that need to be moved to the new file
headers = contents[0]

# Drop the "start" and "end" columns from the headers
# headers.pop(2)
# headers.pop(2)

# Create a new list to store the modified rows
modified_rows = []

# Iterate over the rows in the contents
for row in contents:
    # Drop the "start" and "end" columns from the row
    row.pop(2)
    row.pop(2)
    # Add the modified row to the list
    modified_rows.append(row)

# Open the output CSV file in write mode
with open('output.csv', 'w', newline='') as csv_file:
    # Create a csv.writer object
    writer = csv.writer(csv_file)
    # Write the modified headers to the file
#     writer.writerow(headers)
    # Write the modified rows to the file
    writer.writerows(modified_rows)

# Close the file
csv_file.close()

# %%
# # Open the corrupt data CSV file in read mode
# with open('corrupt_data.csv', 'r') as csv_file:
#     # Create a csv.reader object
#     reader = csv.reader(csv_file)
#     # Read the contents of the file
#     corrupt_data = list(reader)

# # Close the file
# csv_file.close()

# # Remove the headers from the corrupt data list
# headers = corrupt_data[0]
# corrupt_data = corrupt_data[1:]

# # Open the output CSV file in append mode
# with open('output.csv', 'a', newline='') as csv_file:
#     # Create a csv.writer object
#     writer = csv.writer(csv_file)
#     # Write the rows from the corrupt data list to the file
#     writer.writerows(corrupt_data)

# # Close the file
# csv_file.close()

# # Clear the contents of the corrupt data file
# # open('corrupt_data.csv', 'w').close()

# %%
# # Open the output CSV file in read mode
# with open('output.csv', 'r') as csv_file:
#     # Create a csv.reader object
#     reader = csv.reader(csv_file)
#     # Read the contents of the file
#     contents = list(reader)

# # Close the file
# csv_file.close()

# # Get the headers from the contents
# headers = contents[0]

# # Drop the "start" and "end" columns from the headers
# headers.pop(2)
# headers.pop(3)

# # Create a new list to store the modified rows
# modified_rows = []

# # Iterate over the rows in the contents
# for row in contents:
#     # Check if the value in the "recurring" column is "no"
#     if row[7] == "no":
#         # Skip this row and move on to the next one
#         continue
#     # Drop the "start" and "end" columns from the row
#     row.pop(2)
#     row.pop(3)
#     # Add the modified row to the list
#     modified_rows.append(row)


    
# # # Remove duplicate rows from the list
# # unique_rows = []
# # for row in modified_rows:
# #     if row not in unique_rows:
# #         unique_rows.append(row)

# contents3 = [row for row in contents if row not in modified_rows]

# # Open the output CSV file in write mode
# with open('output.csv', 'w', newline='') as csv_file:
#     # Create a csv.writer object
#     writer = csv.writer(csv_file)
#     # Write the modified headers to the file
#     writer.writerow(headers)
#     # take out non recurring mtgs
#     writer.writerow(contents3)
# # Close the file
# csv_file.close()

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('output.csv')

# Remove all duplicate rows from the DataFrame
df = df.drop_duplicates()

# Write the modified DataFrame back to the CSV file
df.to_csv('output.csv', index=False)

# %%
# # Open the input CSV file in read mode
# with open('output.csv', 'r') as csv_file:
#     # Create a csv.reader object
#     reader = csv.reader(csv_file)
#     # Read the contents of the file
#     contents = list(reader)

# # Close the file
# csv_file.close()

# # Store the headers in a separate variable
# headers = contents[0]

# # Create a list to store the rows that need to be moved to the new file
# rows_to_move2 = []

# # Iterate over the rows in the input file
# for row in contents:
#     # Check if the value of the "recurring" column is not "no" or "yes"
#     if row[7] not in ['no', 'yes']:
#         # If the condition is met, add the row to the list of rows to move
#         rows_to_move2.append(row)

# # Open the new CSV file in write mode
# with open('corrupt_data.csv', 'w', newline='') as csv_file:
#     # Create a csv.writer object
#     writer = csv.writer(csv_file)
#     # Write the rows to be moved to the new file
#     writer.writerows(rows_to_move2)

# # Close the file
# csv_file.close()

# # Remove the rows that have been moved to the new file from the original contents
# contents3 = [row for row in contents if row not in rows_to_move2]

# # Open the input CSV file in write mode
# with open('output.csv', 'w', newline='') as csv_file:
#     # Create a csv.writer object
#     writer = csv.writer(csv_file)
    
#     # Write the headers to the file
#     writer.writerow(headers)
    
#     # Write the modified contents of the file to the file
#     writer.writerows(contents3[1:])

# # Close the file
# csv_file.close()

# %%
# Read in the CSV file as a dataframe
df = pd.read_csv('output.csv')

# Split the "recurrence end" column by "T" and assign the resulting dataframe to a new dataframe with the desired column names
df_split = df['recurrence end'].str.split('T', expand=True).rename(columns={0: 'end date', 1: 'time duration'})

# Concatenate the original dataframe and the split dataframe using the `pd.concat` function
df_final = pd.concat([df, df_split], axis=1)

# Drop the original "recurrence end" column
df_final.drop(columns=['recurrence end'], inplace=True)

# %%
# Read in the CSV file using pandas
df = pd.read_csv('output.csv')

# Write the DataFrame to an Excel file
df.to_excel('cal_audit_tool.xlsx', sheet_name = 'recurring_meetings', index=False)

# %%
# Read in the Excel file using pandas
df = pd.read_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings')

# remove 1 attendee entries (likely lunch/time blocks) and non recurring meetings
mask = (df['attendees'] == 1) | (df['recurring'] == 'no')

# Delete the rows that match the mask
df = df[~mask]

# Write the modified DataFrame to the Excel file
df.to_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings', index=False)

# %%
# Read in the Excel file using pandas
path = r"C:\Users\s4508\Documents\audit\cal_audit_tool.xlsx"

# Identify 1:1's from data sheet
mask = df['attendees'] == 2

# Create a new DataFrame with the rows that match the mask
df2 = df[mask]

writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
df.to_excel(writer, sheet_name = 'recurring_meetings')
df2.to_excel(writer, sheet_name = '1_on_1s')
writer.close()

# %%
path = r"C:\Users\s4508\Documents\audit\cal_audit_tool.xlsx"

df_not1on1s = df[~mask]
df2 = df[mask]


writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
df_not1on1s.to_excel(writer, sheet_name = 'recurring_meetings')
df2.to_excel(writer, sheet_name = '1_on_1s')
writer.close()

# %%
# copy meetings you or your leader owns to a new sheet
df = pd.read_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings')

# Identify meetings where you/your leader is the organizer
mask2 = df['response'] == 'ORGANIZER'
df_my_mtgs = df[mask2]
df_not_my_mtgs = df[~mask2]


path = r"C:\Users\s4508\Documents\audit\cal_audit_tool.xlsx"
writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
df_not_my_mtgs.to_excel(writer, sheet_name = 'recurring_meetings')
df2.to_excel(writer, sheet_name = '1_on_1s')
df_my_mtgs.to_excel(writer, sheet_name = 'Meetings_I_Own')


writer.close()

# %%
# # Read in the Excel file using pandas
# df_recurring = pd.read_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings')
# df_1on1s = pd.read_excel('cal_audit_tool.xlsx', sheet_name='1_on_1s')
# df_meetings = pd.read_excel('cal_audit_tool.xlsx', sheet_name='Meetings_I_Own')

# # # Replace all question marks in the data with an empty string
# # df_recurring = df_recurring.replace('?', '')
# # df_1on1s = df_1on1s.replace('?', '')
# # df_meetings = df_meetings.replace('?', '')
# mask = (df['attendees'] == 1)
# df = df[~mask]
# # Write the modified data back to the Excel file
# path = r"C:\Users\s4508\Documents\audit\cal_audit_tool.xlsx"
# writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
# df_recurring.to_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings', index=False)
# df_1on1s.to_excel('cal_audit_tool.xlsx', sheet_name='1_on_1s', index=False)
# df_meetings.to_excel('cal_audit_tool.xlsx', sheet_name='Meetings_I_Own', index=False)

# writer.close()

# %%
# # drop extra columns added
# # Load the workbook
# workbook = load_workbook('cal_audit_tool.xlsx')

# # Read in the "recurring_meetings" sheet as a dataframe
# recurring_meetings_df = pd.read_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings')

# # Drop the "Unnamed: 0" column from the dataframe
# recurring_meetings_df.drop(columns=['Unnamed: 0'], inplace=True)

# # Write the modified dataframe back to the "recurring_meetings" sheet
# recurring_meetings_df.to_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings', index=False)

# # Read in the "Meetings_I_Own" sheet as a dataframe
# meetings_i_own_df = pd.read_excel('cal_audit_tool.xlsx', sheet_name='Meetings_I_Own')

# # Drop the "Unnamed: 0" column from the dataframe
# meetings_i_own_df.drop(columns=['Unnamed: 0'], inplace=True)

# # Write the modified dataframe back to the "Meetings_I_Own" sheet
# meetings_i_own_df.to_excel('cal_audit_tool.xlsx', sheet_name='Meetings_I_Own', index=False)

# # Read
# oneOnones_df = pd.read_excel('cal_audit_tool.xlsx', sheet_name='1_on_1s')

# # Drop
# oneOnones_df.drop(columns=['Unnamed: 0'], inplace=True)

# # Write
# oneOnones_df.to_excel('cal_audit_tool.xlsx', sheet_name='1_on_1s', index=False)

# # Save the workbook
# workbook.save('cal_audit_tool.xlsx')

# %%
# # Clean up recurrence column in first sheet
# df_recur_mtgs = pd.read_excel('cal_audit_tool.xlsx', sheet_name='recurring_meetings')

# # Create a regular expression pattern that matches only letters, numbers, commas, and apostrophes
# pattern = re.compile('[^a-zA-Z0-9,\']')

# # Apply the pattern to the "recurrence" column and remove any characters that do not match
# df_recur_mtgs['recurrence'] = df_recur_mtgs['recurrence'].apply(lambda x: pattern.sub('', x))

# # Clean up recurrence column in second sheet
# df_owned_mtgs = pd.read_excel('cal_audit_tool.xlsx', sheet_name='Meetings_I_Own', index=False)

# # regex for owned meetings sheet
# pattern2 = re.compile('[^a-zA-Z0-9,\']')

# # apply regex
# df_owned_mtgs['recurrence'] = df_owned_mtgs['recurrence'].apply(lambda x: pattern2.sub('', x))

# # Read in 1 on 1's sheet
# df_1_on_ones = pd.read_excel('cal_audit_tool.xlsx', sheet_name='1_on_1s', index=False)

# # regex 1:1 sheet
# pattern3 = re.compile('[^a-zA-Z0-9,\']')

# # apply regex
# df_1_on_ones['recurrence'] = df_1_on_ones['recurrence'].apply(lambda x: pattern3.sub('', x))
